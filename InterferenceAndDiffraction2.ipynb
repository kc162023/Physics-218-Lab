# %%
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline


#Create arrays for your data
p = np.array([1,2,-1,-2])#Order
sin_theta = np.array([0.016,0.033,-0.017,-0.032])

#Create an array for your y-axis uncertainties
err_p = np.array([0.25,0.25,0.25,0.25])
#Reassign variables
x = sin_theta
y = p
dy = err_m

#size the plot
plt.figure(figsize=(15,10))

#create scatter plot
plt.scatter(x, y, color='blue', marker='o')

#create labels
plt.xlabel('sin(theta)')
plt.ylabel('p')
plt.title('p vs sin(theta)')

#fitting to a 2nd degree polynomial
c,b,a=np.polynomial.polynomial.polyfit(x,y,2,w=dy)

#Annotate with values of A, B, C from best fit polynomial
plt.annotate('Slope = {value:.{digits}E}'.format(value=a, digits=3),
             (0.05, 0.9), xycoords='axes fraction')

plt.annotate('Error in slope = {value:.{digits}E}'.format(value=b, digits=3),
             (0.05, 0.85), xycoords='axes fraction')
             
plt.annotate('C = {value:.{digits}E}'.format(value=c, digits=3),
             (0.05, 0.8), xycoords='axes fraction')
#Create fit line
xnew = np.linspace(x.min(), x.max(), 300)
fit = a*xnew**2 + b*xnew +c

plt.scatter(xnew, fit, color='red')
plt.show()

print ("C = ",c , "B = ",b, "A = ",a)
# Out:
# C =  0.051017358706142366 B =  61.392240825389536 A =  -76.77555862474352
